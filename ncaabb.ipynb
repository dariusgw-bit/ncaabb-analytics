# %%
# %pip install -U plotly ipywidgets jupyterlab_widgets widgetsnbextension openpyxl
# %pip install voila
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %run ncaa_claudeai.py
# Out:
# Error importing in API mode: ImportError('On Windows, cffi mode "ANY" is only "ABI".')
# Trying to import in ABI mode.
# ✅ hoopR installed and loaded
# ✅ Paths configured
# RETRAIN CHECK
# force_data=False | force_model=False
# DATA REFRESH
# Triggered (last: 2026-03-20T22:13:27.326640)
# DATA LOAD
# team_box rows: 81,998 | schedule rows: 6,318
# Building rolling snapshots + Elo...
# MODEL STATUS
# Model is fresh (last fit: 2026-03-20T22:13:27.326640). Loading from disk.
# ✅ Models loaded from disk
# RETRAIN COMPLETE
# Scheduler complete. All globals ready.
# [Dashboard] latest_data_date= | schedule_rows=6,318 | team_snaps=81,998 | odds_rows=19 | model_last_trained=2026-03-20T22:13:27.326640 | data_refresh=executed | model_refresh=skipped
# ...
# Output()
