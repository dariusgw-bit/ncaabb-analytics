# %%
# %pip install -U plotly ipywidgets jupyterlab_widgets widgetsnbextension openpyxl
# %pip install voila
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %run ncaa_claudeai.py
# Out:
# Error importing in API mode: ImportError('On Windows, cffi mode "ANY" is only "ABI".')
# Trying to import in ABI mode.
# ✅ hoopR installed and loaded
# ✅ Paths configured
# Starting retrain check: force_data=False, force_model=False
# Data refresh skipped (last: 2026-03-20T20:41:20.291224)
# Loading team box history...
#   team_box rows: 81,970  |  schedule rows: 6,318
# Building rolling snapshots + Elo...
# Model is fresh (last fit: 2026-03-20T20:41:20.291224). Loading from disk.
# ✅ Models loaded from disk
# Scheduler complete. All globals ready.
# [Dashboard] latest_data_date= | schedule_rows=6,318 | team_snaps=81,970 | odds_rows=24 | model_last_trained=2026-03-20T20:41:20.291224 | data_refresh=skipped | model_refresh=skipped
# ...
# Output()
