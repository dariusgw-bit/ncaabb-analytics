# %%
# %pip install plotly
# %pip install ipywidgets widgetsnbextension jupyterlab_widgets
# !pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %run ncaa_claudeai.py
# Out:
# Error importing in API mode: ImportError('On Windows, cffi mode "ANY" is only "ABI".')
# Trying to import in ABI mode.
# ✅ hoopR installed and loaded
# ✅ Paths configured
# 🚀 Running startup retrain check...
# 📂 Loading team box history...
#   team_box rows: 81,890  |  schedule rows: 6,318
# 📊 Building rolling snapshots + Elo...
# ⏭️  Model is fresh (last fit: 2026-03-16T11:24:31.139635). Loading from disk.
# ✅ Models loaded from disk
# ✅ Scheduler complete. All globals ready.
# ...
# Output()
